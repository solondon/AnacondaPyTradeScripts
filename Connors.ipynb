# %%
import pandas as pd

# %%
import pandas_datareader as pdr

# %%
import numpy as np

# %%
df=pdr.get_data_yahoo('AAPL') # Apple Stock
#df=pdr.get_data_yahoo('GC')
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2010-01-04  30.642857  30.340000  30.490000  30.572857  123432400.0  26.681330
# 2010-01-05  30.798571  30.464285  30.657143  30.625713  150476200.0  26.727465
# 2010-01-06  30.747143  30.107143  30.625713  30.138571  138040000.0  26.302330
# 2010-01-07  30.285715  29.864286  30.250000  30.082857  119282800.0  26.253704
# 2010-01-08  30.285715  29.865715  30.042856  30.282858  111902700.0  26.428249

# %%
df.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2019-09-16  220.130005  217.559998  217.729996  219.899994  21158100.0
# 2019-09-17  220.820007  219.119995  219.960007  220.699997  18318700.0
# 2019-09-18  222.850006  219.440002  221.059998  222.770004  25340000.0
# 2019-09-19  223.759995  220.369995  222.009995  220.960007  22060600.0
# 2019-09-20  222.559998  217.470001  221.380005  217.729996  55413100.0
#
#              Adj Close
# Date
# 2019-09-16  219.899994
# 2019-09-17  220.699997
# 2019-09-18  222.770004
# 2019-09-19  220.960007
# 2019-09-20  217.729996

# %%
print(df)
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2010-01-04   30.642857   30.340000   30.490000   30.572857  123432400.0
# 2010-01-05   30.798571   30.464285   30.657143   30.625713  150476200.0
# 2010-01-06   30.747143   30.107143   30.625713   30.138571  138040000.0
# 2010-01-07   30.285715   29.864286   30.250000   30.082857  119282800.0
# 2010-01-08   30.285715   29.865715   30.042856   30.282858  111902700.0
# 2010-01-11   30.428572   29.778572   30.400000   30.015715  115557400.0
# 2010-01-12   29.967142   29.488571   29.884285   29.674286  148614900.0
# 2010-01-13   30.132856   29.157143   29.695715   30.092857  151473000.0
# 2010-01-14   30.065714   29.860001   30.015715   29.918571  108223500.0
# 2010-01-15   30.228571   29.410000   30.132856   29.418571  148516900.0
# 2010-01-19   30.741428   29.605715   29.761429   30.719999  182501900.0
# 2010-01-20   30.792856   29.928572   30.701429   30.247143  153038200.0
# ...

# %%
data_source=r'E:\PYDATA\AAPL.xlsx'
df.to_excel(data_source)

# %%
datafile=r'E:\PYDATA\AAPL.xlsx'
df=pd.read_excel(datafile)
df.tail()
# Out:
#            Date        High         Low        Open       Close    Volume  \
# 2441 2019-09-16  220.130005  217.559998  217.729996  219.899994  21158100
# 2442 2019-09-17  220.820007  219.119995  219.960007  220.699997  18318700
# 2443 2019-09-18  222.850006  219.440002  221.059998  222.770004  25340000
# 2444 2019-09-19  223.759995  220.369995  222.009995  220.960007  22060600
# 2445 2019-09-20  222.559998  217.470001  221.380005  217.729996  55413100
#
#        Adj Close
# 2441  219.899994
# 2442  220.699997
# 2443  222.770004
# 2444  220.960007
# 2445  217.729996

# %%
class Strategy:
    def__init__(self):
        self.strategy_name=strategy_name
        self.long_moving_avg=l_mav
        self.short_moving_avg=s_mav
        
#global variables
strategy_name='Connors' # testing Connors rsi
l_mav= 200
s_mav=5
# Out:
#   File "<ipython-input-15-b7e676538ab6>", line 2
#     def__init__(self):
#                       ^
# SyntaxError: invalid syntax
